# %% [markdown]
# <a href="https://colab.research.google.com/github/pradhicsha6/Plant_Disease_Detection/blob/main/Uva_GoogleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/drive/MyDrive/summer_project/New_Dataset/Training_80%'
valid_path = '/content/drive/MyDrive/summer_project/New_Dataset/Testing_10%'

# %%
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in inception.layers:
    layer.trainable = False

# %%
folders = glob('/content/drive/MyDrive/summer_project/New_Dataset/Training_80%/*')

# %%
x = Flatten()(inception.output)

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=inception.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_658 (Conv2D)            (None, 111, 111, 32  864         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_658 (Batch  (None, 111, 111, 32  96         ['conv2d_658[0][0]']
#  Normalization)                 )
#
#  activation_658 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_658[0][0]']
#                                 )
#
#  conv2d_659 (Conv2D)            (None, 109, 109, 32  9216        ['activation_658[0][0]']
#                                 )
#
#  batch_normalization_659 (Batch  (None, 109, 109, 32  96         ['conv2d_659[0][0]']
#  Normalization)                 )
#
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/summer_project/New_Dataset/Training_80%',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 16530 images belonging to 15 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/summer_project/New_Dataset/Testing_10%',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 2068 images belonging to 15 classes.

# %%
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 143/517 [=======>......................] - ETA: 50:34 - loss: 5.7593 - accuracy: 0.5758
