# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 224

# %%
# Image Resizing
dataset = tf.keras.preprocessing.image_dataset_from_directory(
  "PlantVillage",
image_size = (IMAGE_SIZE,IMAGE_SIZE)
)
# Out:
# Found 20638 files belonging to 15 classes.

# %%
# Convert from RGB to Grayscale Images
import cv2
import glob
import os

os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Pepper__bell___Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___Bacterial_spot/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Pepper__bell___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___healthy/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Potato___Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Potato___Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Potato___Early_blight/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Potato___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Potato___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Potato___healthy/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Potato___Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Potato___Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Potato___Late_blight/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Target_Spot')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato__Target_Spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Target_Spot/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_mosaic_virus')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato__Tomato_mosaic_virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_mosaic_virus/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_YellowLeaf__Curl_Virus')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato__Tomato_YellowLeaf__Curl_Virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_YellowLeaf__Curl_Virus/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Bacterial_spot/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Early_blight/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_healthy')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_healthy/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Late_blight/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Leaf_Mold')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Leaf_Mold/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Leaf_Mold/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Septoria_leaf_spot')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Septoria_leaf_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Septoria_leaf_spot/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Spider_mites_Two_spotted_spider_mite')
images_path = glob.glob('C:/Users/haris/Source Code/RGB/Tomato_Spider_mites_Two_spotted_spider_mite/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    gray_images = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('Grayscale Images',gray_images)
    cv2.imwrite('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Spider_mites_Two_spotted_spider_mite/image%02i.jpg' %i, gray_images)
    i += 1
  
    cv2.destroyAllWindows

# %%
# Convert from Grayscale to Binary Images
import cv2
import glob
import os

os.mkdir('C:/Users/haris/Source Code/Binary_Images/Pepper__bell___Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Pepper__bell___Bacterial_spot/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Pepper__bell___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Pepper__bell___healthy/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Potato___Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Potato___Early_blight/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Potato___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Potato___healthy/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Potato___Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Potato___Late_blight/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato__Target_Spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Target_Spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato__Target_Spot/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato__Tomato_mosaic_virus')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_mosaic_virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato__Tomato_mosaic_virus/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato__Tomato_YellowLeaf__Curl_Virus')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_YellowLeaf__Curl_Virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato__Tomato_YellowLeaf__Curl_Virus/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Bacterial_spot/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Early_blight/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_healthy/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Late_blight/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Leaf_Mold')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Leaf_Mold/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Leaf_Mold/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Septoria_leaf_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Septoria_leaf_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Septoria_leaf_spot/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Binary_Images/Tomato_Spider_mites_Two_spotted_spider_mite')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Spider_mites_Two_spotted_spider_mite/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    ret, binary_images = cv2.threshold(img, 130,257,cv2.THRESH_BINARY)
    cv2.imshow('Binary Images',binary_images)
    cv2.imwrite('C:/Users/haris/Source Code/Binary_Images/Tomato_Spider_mites_Two_spotted_spider_mite/image%02i.jpg' %i, binary_images)
    i += 1
  
    cv2.destroyAllWindows

# %%
# Convert from Grayscale to Filtered Images(removing noises)
import cv2
import numpy as np
import os
import glob
from matplotlib import pyplot as plt

os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Pepper__bell___Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Pepper__bell___Bacterial_spot/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Pepper__bell___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Pepper__bell___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Pepper__bell___healthy/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Potato___Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Potato___Early_blight/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Potato___healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Potato___healthy/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Potato___Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Potato___Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Potato___Late_blight/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato__Target_Spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Target_Spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato__Target_Spot/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato__Tomato_mosaic_virus')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_mosaic_virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato__Tomato_mosaic_virus/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato__Tomato_YellowLeaf__Curl_Virus')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato__Tomato_YellowLeaf__Curl_Virus/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato__Tomato_YellowLeaf__Curl_Virus/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Bacterial_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Bacterial_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Bacterial_spot/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Early_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Early_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Early_blight/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_healthy')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_healthy/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_healthy/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Late_blight')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Late_blight/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Late_blight/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Leaf_Mold')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Leaf_Mold/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Leaf_Mold/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Septoria_leaf_spot')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Septoria_leaf_spot/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Septoria_leaf_spot/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
    
os.mkdir('C:/Users/haris/Source Code/Filtered_Images/Tomato_Spider_mites_Two_spotted_spider_mite')
images_path = glob.glob('C:/Users/haris/Source Code/Grayscale_Images/Tomato_Spider_mites_Two_spotted_spider_mite/*.jpg')

i = 0
for image in images_path:
    img = cv2.imread(image)
    sliding_window_size_x = 5
    sliding_window_size_y = 5
    mean_filter_kernel = np.ones((sliding_window_size_x,sliding_window_size_y),np.float32)/(sliding_window_size_x*sliding_window_size_y)
    filtered_image = cv2.filter2D(img,-1,mean_filter_kernel)
   
    cv2.imwrite('C:/Users/haris/Source Code/Filtered_Images/Tomato_Spider_mites_Two_spotted_spider_mite/image%02i.jpg' %i, filtered_image)
    i += 1
  
    cv2.destroyAllWindows
